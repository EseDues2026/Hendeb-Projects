# %% [markdown]
# <a href="https://colab.research.google.com/github/EseDues2026/Hendeb-Projects/blob/main/Hands_on_class2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
string s, t,"2", float 2.3, 1.2,

# %%
#list
class = ["student","book","bag","pen"] variable
# Out:
# 6

# %%
plants = ["Azadirachta indica", “Tamarind indica”, "Parkia biglobosa”]

# %%
# Installing essential libraries for Cheminformatics and Bioinformatics
# !pip install rdkit pandas scikit-learn pubchempy biopython
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.0/37.0 MB 16.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 48.4 MB/s eta 0:00:00
# ...

# %%
plants = ["Azadirachta indica","Tamarind indica", "Parkia biglobosa"]

# %%
# A list of plants for phytochemical profiling
plants = ["Azadirachta indica", "Tamarind indica", "Parkia biglobosa","mango","guava"]
print(f"Plant: {plants[4]}")
# Out:
# Plant: guava

# %%
# DICTIONARY
# Mapping compounds to biological activity (QSAR)
assay_results = {"Lead_01": 0.05, "Lead_02": 12.4}
print(f"Activity of Lead_02: {assay_results['Lead_02']} uM")
# Out:
# Activity of Lead_02: 12.4 uM

# %%
from rdkit import Chem
from rdkit.Chem import Descriptors


smiles_list = ["CCO","C1=CC=CC=C1","c1ccccc1","CCCO"]

for smiles in smiles_list:
  molar_weight = Chem.MolFromSmiles(smiles)
  print(f"{smiles}: {Descriptors.MolWt(mol):.2f} g/mol")
# Out:
# CCO: 46.07 g/mol
# C1=CC=CC=C1: 78.11 g/mol
# c1ccccc1: 78.11 g/mol
# CCCO: 60.10 g/mol

# %%
# while loop
toxicity = 0.8
while toxicity > 0.2:
  print(f"Toxicity at {toxicity}: Optimizing structure...")
  toxicity -= 0.2 # Reduce toxicity iteratively
# Out:
# Toxicity at 0.8: Optimizing structure...
# Toxicity at 0.6000000000000001: Optimizing structure...
# Toxicity at 0.4000000000000001: Optimizing structure...
# Toxicity at 0.20000000000000007: Optimizing structure...

# %%
temperature = 40 # degree celcius
while temperature > 15:
    print(f"comfortable temperature at {temperature}°C: reducing hot!")
    temperature -= 5 # Cools down 5 degree each minute
# Out:
# comfortable temperature at 40°C: reducing hot!
# comfortable temperature at 35°C: reducing hot!
# comfortable temperature at 30°C: reducing hot!
# comfortable temperature at 25°C: reducing hot!
# comfortable temperature at 20°C: reducing hot!

# %% [markdown]
# # New Section
